# %%
# !pip3 install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas>=1.3.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: matplotlib>=3.4.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: scipy>=1.7.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: ipykernel in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 7)) (6.29.4)
# Requirement already satisfied: networkx in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 8)) (3.2.1)
# Requirement already satisfied: xgboost in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 9)) (2.1.4)
# Requirement already satisfied: helper in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: pydantic-ai in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 11)) (0.0.52)
# Requirement already satisfied: imbalanced-learn in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 12)) (0.12.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pandas>=1.3.0->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pandas>=1.3.0->-r requirements.txt (line 1)) (2021.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (6.1.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: appnope in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipykernel->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: pyyaml in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from helper->-r requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: pydantic-ai-slim==0.0.52 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.0.52)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.2.2)
# Requirement already satisfied: exceptiongroup in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: griffe>=1.3.2 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.7.2)
# Requirement already satisfied: httpx>=0.27 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.31.1)
# Requirement already satisfied: pydantic-graph==0.0.52 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.0.52)
# Requirement already satisfied: pydantic>=2.10 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (2.11.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: boto3>=1.34.116 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.37.28)
# Requirement already satisfied: groq>=0.15.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.22.0)
# Requirement already satisfied: openai>=1.67.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.70.0)
# Requirement already satisfied: cohere>=5.13.11 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (5.14.2)
# Requirement already satisfied: argcomplete>=3.5.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (3.6.2)
# Requirement already satisfied: prompt-toolkit>=3 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (3.0.45)
# Requirement already satisfied: rich>=13 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (14.0.0)
# Requirement already satisfied: google-auth>=2.36.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (2.38.0)
# Requirement already satisfied: requests>=2.32.3 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (2.32.3)
# Requirement already satisfied: mistralai>=1.2.5 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: anthropic>=0.49.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.49.0)
# Requirement already satisfied: pydantic-evals==0.0.52 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.0.52)
# Requirement already satisfied: anyio>=0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-evals==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (4.1.0)
# Requirement already satisfied: logfire-api>=1.2.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic-evals==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (3.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.4.0->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: decorator in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (2.18.0)
# Requirement already satisfied: stack-data in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (4.13.1)
# Requirement already satisfied: pexpect>4.3 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 7)) (7.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 7)) (4.2.2)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.3.0->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: sniffio in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from anthropic>=0.49.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: botocore<1.38.0,>=1.37.28 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from boto3>=1.34.116->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.37.28)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from boto3>=1.34.116->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from boto3>=1.34.116->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.11.4)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (2.33.1)
# Requirement already satisfied: tokenizers<1,>=0.15 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.19.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (2.31.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (4.9)
# Requirement already satisfied: colorama>=0.4 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from griffe>=1.3.2->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: certifi in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.0.2)
# Requirement already satisfied: idna in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from httpx>=0.27->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: tqdm>4 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from openai>=1.67.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (4.66.4)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.2.18)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit>=3->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.3->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.3->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.26.16)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.28.0->pydantic-ai-slim==0.0.52->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (0.23.2)
# Requirement already satisfied: types-urllib3 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from types-requests<3.0.0,>=2.0.0->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (1.26.25.14)
# Requirement already satisfied: filelock in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,groq,mcp,mistral,openai,vertexai]==0.0.52->pydantic-ai->-r requirements.txt (line 11)) (2024.5.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 25.1.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.patches import Ellipse
import seaborn as sns
import glob
from scipy.spatial import ConvexHull
from scipy.optimize import linear_sum_assignment
from scipy.stats import multivariate_normal
from scipy.spatial import Delaunay
from sklearn.cluster import KMeans
import warnings
import json
import networkx as nx
warnings.simplefilter(action='ignore', category=FutureWarning)
from pandas.errors import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
from scipy.linalg import sqrtm
from scipy.optimize import linear_sum_assignment
from utils import *

# %%
def wasserstein_distance_gaussian(mean1, cov1, mean2, cov2):
    # Compute the squared difference between the means.
    mean_diff_sq = np.linalg.norm(mean1 - mean2)**2

    # Compute the matrix square root of cov1
    cov1_sqrt = sqrtm(cov1)
    
    # Compute the product cov1_sqrt * cov2 * cov1_sqrt
    product = cov1_sqrt @ cov2 @ cov1_sqrt
    
    # Compute the square root of the product matrix
    sqrt_product = sqrtm(product)
    
    # Compute the trace term
    trace_term = np.trace(cov1 + cov2 - 2 * sqrt_product)
    
    # Return the 2-Wasserstein distance (ensure non-negative)
    return np.sqrt(max(mean_diff_sq + trace_term, 0))

# %%
def compute_emd(formation1, formation2):
    # formation1 and formation2 are lists of 10 players: (mean, covariance)
    n = len(formation1)
    m = len(formation2)
    cost_matrix = np.zeros((n, m))
    
    for i in range(n):
        for j in range(m):
            mean1, cov1 = formation1[i]
            mean2, cov2 = formation2[j]
            cost_matrix[i, j] = wasserstein_distance_gaussian(mean1, cov1, mean2, cov2)
    
    # Solve the assignment problem (Hungarian algorithm)
    row_ind, col_ind = linear_sum_assignment(cost_matrix)
    total_cost = cost_matrix[row_ind, col_ind].sum()
    
    # Since each player has equal weight (1/10), the EMD is the total_cost divided by the total mass (which is 1)
    return total_cost

# %%
with open('tracks.json', 'r') as f:
    tracks_z14 = json.load(f)

with open('tracks_extern_data.json', 'r') as f:
    tracks_extern = json.load(f)

# %%
# with open('tracks.json', 'r') as f:
#     tracks_z14 = json.load(f)

with open('tracks.json', 'r') as f:
    tracks_z14 = json.load(f)

with open('extern_adjusted_tracks_mirrored_5min_window.json', 'r') as f:
    tracks_extern = json.load(f)

with open('adjusted_tracks_mirroed_5-10min_window_2.json', 'r') as f:
    tracks_extern_2 = json.load(f)

# %%
# Merge the two JSON structures
combined_data = {**tracks_z14, **tracks_extern, **tracks_extern_2}

# Save the merged result
with open("merged.json", "w") as output_file:
    json.dump(combined_data, output_file, indent=4)

print("Merged JSON saved as 'merged.json'")
# Out:
# Merged JSON saved as 'merged.json'

# %%
formations = []  # List to store each team's formation as a list of players.
team_names = []  # To keep track of team IDs

for team, roles in combined_data.items():
    for role_key, players in roles.items():
        if not players:  # Skip if the role is an empty object
            continue
        formation = []
        for player, stats in players.items():
            mean = np.array(stats['mean'])          
            covariance = np.array(stats['covariance']) 
            formation.append((mean, covariance))
        formations.append(formation)
        team_names.append(f"{team}_{role_key}")

num_formations = len(formations)
print(f"Number of formations: {num_formations}")
distance_matrix = np.zeros((num_formations, num_formations))

for i in range(num_formations):
    for j in range(i + 1, num_formations):
        distance = compute_emd(formations[i], formations[j])
        distance_matrix[i, j] = distance
        distance_matrix[j, i] = distance  # distance is symmetric
# Out:
# Number of formations: 57

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform

condensed_distance = squareform(distance_matrix)

linkage_matrix = linkage(condensed_distance, method='ward')

plt.figure(figsize=(12, 8))
dendrogram(linkage_matrix, labels=team_names, leaf_rotation=90, leaf_font_size=10)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Team / Formation')
plt.ylabel('EMD Distance')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/6t/2kykm1l51vv3mrsbvhz5jznc0000gn/T/ipykernel_9480/4042286385.py:15: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
from sklearn.cluster import AgglomerativeClustering

# Correct the metric parameter to a valid value, e.g., 'euclidean'
clustering = AgglomerativeClustering(
    n_clusters=4,
    metric='euclidean',  # Use a valid distance metric
    linkage='ward'  # Try different linkage methods
)

cluster_labels = clustering.fit_predict(distance_matrix)

for team, label in zip(team_names, cluster_labels):
    print(f"Team {team} is in cluster {label}")
# Out:
# Team ./xy_data/fis2_data.txt_roles_0 is in cluster 3
# Team ./xy_data/fis2_data.txt_roles_1 is in cluster 1
# Team ./xy_data/gr2_data.txt_roles_0 is in cluster 1
# Team ./xy_data/gr2_data.txt_roles_1 is in cluster 0
# Team ./xy_data/t1_data.txt_roles_0 is in cluster 1
# Team ./xy_data/t1_data.txt_roles_1 is in cluster 2
# Team ./xy_data/st2_data.txt_roles_0 is in cluster 1
# Team ./xy_data/st2_data.txt_roles_1 is in cluster 1
# Team ./xy_data/stv2_data.txt_roles_0 is in cluster 1
# Team ./xy_data/stv2_data.txt_roles_1 is in cluster 2
# Team ./xy_data/m1_data.txt_roles_0 is in cluster 2
# Team ./xy_data/m1_data.txt_roles_1 is in cluster 2
# Team ./xy_data/friedr2_data.txt_roles_0 is in cluster 1
# Team ./xy_data/friedr2_data.txt_roles_1 is in cluster 2
# Team ./xy_data/t2_data.txt_roles_0 is in cluster 1
# Team ./xy_data/t2_data.txt_roles_1 is in cluster 2
# Team ./xy_data/alt_data.txt_roles_0 is in cluster 2
# Team ./xy_data/alt_data.txt_roles_1 is in cluster 2
# Team ./xy_data/alt2_data.txt_roles_0 is in cluster 2
# Team ./xy_data/alt2_data.txt_roles_1 is in cluster 2
# Team ./xy_data/fis1_data.txt_roles_0 is in cluster 3
# Team ./xy_data/fis1_data.txt_roles_1 is in cluster 1
# Team ./xy_data/gr1_data.txt_roles_0 is in cluster 2
# Team ./xy_data/gr1_data.txt_roles_1 is in cluster 0
# Team ./xy_data/m2_data.txt_roles_0 is in cluster 2
# Team ./xy_data/m2_data.txt_roles_1 is in cluster 2
# Team ./xy_data/stv1_data.txt_roles_0 is in cluster 3
# Team ./xy_data/st1_data.txt_roles_0 is in cluster 1
# Team ./xy_data/st1_data.txt_roles_1 is in cluster 1
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX.xml_DFL-CLU-00000G is in cluster 1
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX.xml_DFL-CLU-000008 is in cluster 2
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1.xml_DFL-CLU-00000S is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1.xml_DFL-CLU-00000B is in cluster 1
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ.xml_DFL-CLU-00000P is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ.xml_DFL-CLU-00000H is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9.xml_DFL-CLU-00000I is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9.xml_DFL-CLU-00000P is in cluster 2
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY.xml_DFL-CLU-00000P is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY.xml_DFL-CLU-000005 is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH.xml_DFL-CLU-00000P is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH.xml_DFL-CLU-000011 is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY.xml_DFL-CLU-00000Q is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY.xml_DFL-CLU-00000P is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX_2.xml_DFL-CLU-00000G is in cluster 2
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX_2.xml_DFL-CLU-000008 is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1_2.xml_DFL-CLU-00000S is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1_2.xml_DFL-CLU-00000B is in cluster 1
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ_2.xml_DFL-CLU-00000P is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ_2.xml_DFL-CLU-00000H is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9_2.xml_DFL-CLU-00000I is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9_2.xml_DFL-CLU-00000P is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY_2.xml_DFL-CLU-00000P is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY_2.xml_DFL-CLU-000005 is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH_2.xml_DFL-CLU-00000P is in cluster 3
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH_2.xml_DFL-CLU-000011 is in cluster 2
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY_2.xml_DFL-CLU-00000Q is in cluster 0
# Team ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY_2.xml_DFL-CLU-00000P is in cluster 3
# /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages/scipy/cluster/hierarchy.py:796: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Create a heatmap for the distance matrix
plt.figure(figsize=(12, 10))
sns.heatmap(distance_matrix, xticklabels=team_names, yticklabels=team_names, cmap='viridis', annot=False)
plt.title('Distance Matrix Heatmap')
plt.xlabel('Teams/Formations')
plt.ylabel('Teams/Formations')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.cm as cm

unique_clusters = np.unique(cluster_labels)
colors = cm.get_cmap('tab20', len(unique_clusters))  # Up to 10 distinct colors
print(f"Unique clusters: {unique_clusters}")
mycolors = ["yellow", "blue", "red", "green", "purple", "orange", "pink", "brown", "gray", "cyan", "magenta", "black", "teal", "navy", "lime", "coral", "salmon", "gold", "violet", "indigo"]
for cluster_label in unique_clusters:
    formations_in_cluster = [formations[i] for i in range(len(cluster_labels)) if cluster_labels[i] == cluster_label]
    team_names_in_cluster = [team_names[i] for i in range(len(cluster_labels)) if cluster_labels[i] == cluster_label]
    print(f"Cluster {cluster_label} contains {len(formations_in_cluster)} teams.")

    plt.figure(figsize=(10, 8))
    plt.title(f"Overlay of Formations in Cluster {cluster_label}", fontsize=16)
    plt.xlabel('X Coordinate', fontsize=12)
    plt.ylabel('Y Coordinate', fontsize=12)
    plt.grid(True)
    plt.axis('equal')  # preserves formation proportions

    cluster_color = colors(cluster_label)
    all_means = []

    for idx, formation in enumerate(formations_in_cluster):
        for mean, cov in formation:
            all_means.append(mean)
            eigenvalues, eigenvectors = np.linalg.eigh(cov)
            order = eigenvalues.argsort()[::-1]
            eigenvalues, eigenvectors = eigenvalues[order], eigenvectors[:, order]
            angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigenvalues)

            plt.scatter(mean[0], mean[1], s=30, color=mycolors[idx])

    all_means = np.array(all_means)
    kmeans = KMeans(n_clusters=10, random_state=42)
    kmeans.fit(all_means)
    cluster_centers = kmeans.cluster_centers_

    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], s=200, marker='X', color="black" ,label='KMeans Centers')

    # Add team names to the legend
    legend_labels = [f"{team_name}" for team_name in team_names_in_cluster]
    print("Teams" , legend_labels)

    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/6t/2kykm1l51vv3mrsbvhz5jznc0000gn/T/ipykernel_9480/774803336.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap('tab20', len(unique_clusters))  # Up to 10 distinct colors
# Unique clusters: [0 1 2 3]
# Cluster 0 contains 12 teams.
# Teams ['./xy_data/gr2_data.txt_roles_1', './xy_data/gr1_data.txt_roles_1', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1.xml_DFL-CLU-00000S', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ.xml_DFL-CLU-00000H', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH.xml_DFL-CLU-000011', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1_2.xml_DFL-CLU-00000S', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ_2.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ_2.xml_DFL-CLU-00000H', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY_2.xml_DFL-CLU-00000Q']
# Cluster 1 contains 14 teams.
# Teams ['./xy_data/fis2_data.txt_roles_1', './xy_data/gr2_data.txt_roles_0', './xy_data/t1_data.txt_roles_0', './xy_data/st2_data.txt_roles_0', './xy_data/st2_data.txt_roles_1', './xy_data/stv2_data.txt_roles_0', './xy_data/friedr2_data.txt_roles_0', './xy_data/t2_data.txt_roles_0', './xy_data/fis1_data.txt_roles_1', './xy_data/st1_data.txt_roles_0', './xy_data/st1_data.txt_roles_1', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX.xml_DFL-CLU-00000G', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1.xml_DFL-CLU-00000B', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1_2.xml_DFL-CLU-00000B']
# Cluster 2 contains 17 teams.
# Teams ['./xy_data/t1_data.txt_roles_1', './xy_data/stv2_data.txt_roles_1', './xy_data/m1_data.txt_roles_0', './xy_data/m1_data.txt_roles_1', './xy_data/friedr2_data.txt_roles_1', './xy_data/t2_data.txt_roles_1', './xy_data/alt_data.txt_roles_0', './xy_data/alt_data.txt_roles_1', './xy_data/alt2_data.txt_roles_0', './xy_data/alt2_data.txt_roles_1', './xy_data/gr1_data.txt_roles_0', './xy_data/m2_data.txt_roles_0', './xy_data/m2_data.txt_roles_1', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX.xml_DFL-CLU-000008', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX_2.xml_DFL-CLU-00000G', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH_2.xml_DFL-CLU-000011']
# Cluster 3 contains 14 teams.
# Teams ['./xy_data/fis2_data.txt_roles_0', './xy_data/fis1_data.txt_roles_0', './xy_data/stv1_data.txt_roles_0', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9.xml_DFL-CLU-00000I', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY.xml_DFL-CLU-000005', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY.xml_DFL-CLU-00000Q', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX_2.xml_DFL-CLU-000008', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9_2.xml_DFL-CLU-00000I', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9_2.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY_2.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY_2.xml_DFL-CLU-000005', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH_2.xml_DFL-CLU-00000P', './data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY_2.xml_DFL-CLU-00000P']

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from matplotlib.cm import get_cmap

for cluster_label in np.unique(cluster_labels):
    formations_in_cluster = [formations[i] for i in range(len(cluster_labels)) if cluster_labels[i] == cluster_label]
    team_names_in_cluster = [team_names[i] for i in range(len(cluster_labels)) if cluster_labels[i] == cluster_label]

    plt.figure(figsize=(10, 8))
    plt.title(f"Overlay of Formations in Cluster {cluster_label}")

    # Generate a colormap with enough distinct colors
    cmap = get_cmap('tab20', len(team_names_in_cluster))  
    team_colors = {team: cmap(i / len(team_names_in_cluster)) for i, team in enumerate(team_names_in_cluster)}

    all_means = []
    for formation, team_name in zip(formations_in_cluster, team_names_in_cluster):
        team_color = team_colors[team_name]
        
        for mean, cov in formation:
            all_means.append(mean)
            eigenvalues, eigenvectors = np.linalg.eigh(cov)
            order = eigenvalues.argsort()[::-1]
            eigenvalues, eigenvectors = eigenvalues[order], eigenvectors[:, order]
            angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigenvalues)
            
            ell = Ellipse(xy=mean, width=width, height=height, angle=angle, fc='None')
            plt.gca().add_patch(ell)
            plt.scatter(mean[0], mean[1], s=100, color=team_color, label=team_name)

    all_means = np.array(all_means)
    kmeans = KMeans(n_clusters=10)
    kmeans.fit(all_means)
    cluster_centers = kmeans.cluster_centers_
    
    
    
    # Remove duplicate legend entries
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(), loc='best', fontsize='small', title='Teams', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
    
    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], s=200, c='red', marker='X')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.show()
# Out:
# /var/folders/6t/2kykm1l51vv3mrsbvhz5jznc0000gn/T/ipykernel_9480/226452437.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap('tab20', len(team_names_in_cluster))
# /var/folders/6t/2kykm1l51vv3mrsbvhz5jznc0000gn/T/ipykernel_9480/226452437.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap('tab20', len(team_names_in_cluster))
# /var/folders/6t/2kykm1l51vv3mrsbvhz5jznc0000gn/T/ipykernel_9480/226452437.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap('tab20', len(team_names_in_cluster))
# /var/folders/6t/2kykm1l51vv3mrsbvhz5jznc0000gn/T/ipykernel_9480/226452437.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap('tab20', len(team_names_in_cluster))

# %%
import json

# Load JSON data
with open("merged.json", "r") as file:  # Change filename as needed
    data = json.load(file)

team_feature_vectors = {}

# Iterate over each dataset (e.g., "./xy_data/fis2_data.txt", "./xy_data/fis3_data.txt")
for dataset_key, teams in data.items():
    team_feature_vectors[dataset_key] = {}  # Store feature vectors per dataset

    # Iterate over each team (e.g., "roles_0", "roles_1")
    for team_key, players in teams.items():
        team_vector = []  # Store concatenated feature vector for this team

        # Ensure we process exactly 10 players in order
        player_keys = sorted(players.keys(), key=int)[:10]  # Sort to maintain order

        for player_key in player_keys:
            player_data = players[player_key]

            # Extract mean values
            mean = player_data["mean"]

            # Extract covariance values (flattened: σ11, σ12, σ22)
            cov_matrix = player_data["covariance"]
            cov_vector = [cov_matrix[0][0], cov_matrix[0][1], cov_matrix[1][1]]

            # Concatenate mean and covariance to form the player vector
            player_vector = mean + cov_vector

            # Append player vector to team vector
            team_vector.extend(player_vector)

        # Store the final 50D team vector
        team_feature_vectors[dataset_key][team_key] = team_vector

# Print results
for dataset, teams in team_feature_vectors.items():
    print(f"\nDataset: {dataset}")
    for team, vector in teams.items():
        print(f"  {team}: {vector[:10]}... (total {len(vector)} values)")  # Showing first 10 values for brevity
# Out:
# Dataset: ./xy_data/fis2_data.txt
#   roles_0: [1.5126780626780614, 15.540898326210822, 22.263504980792142, 6.1418699357978, 28.046773127832704, -8.283169344042845, -12.538612672913867, 47.46618221283667, 13.633391062478443, 25.711848710164386]... (total 50 values)
#   roles_1: [9.92371314699794, -13.122898033126296, 27.20076200588236, -4.943709718209393, 20.9948210073675, -14.884170579940768, 6.128014029572703, 17.914935389409994, -0.42121759943392145, 14.529165002302655]... (total 50 values)
#
# Dataset: ./xy_data/gr2_data.txt
#   roles_0: [-9.297925333333344, 18.651561777777797, 20.85713813515524, 7.431810614249028, 22.580150772826464, 10.443034666666666, -1.2150782222222214, 13.83335089373543, -3.536960720827919, 30.025001028284166]... (total 50 values)
#   roles_1: [-1.6184343029979544, -23.644908815941644, 41.747830349730876, 10.882874461296643, 43.359266094727644, 7.975589333333315, 11.305216000000005, 29.304073471957615, 3.896224750059007, 18.56000646567703]... (total 50 values)
#
# Dataset: ./xy_data/t1_data.txt
#   roles_0: [-10.791412539045083, 19.187548256518145, 11.033916224293563, 1.5924947393613276, 32.70097794920643, 6.1961224909026935, -6.609360807867377, 24.93921120256427, -1.027245118724092, 21.854309554242874]... (total 50 values)
#   roles_1: [8.09927522273853, 17.217763778016096, 20.560750269877953, -4.176846057848476, 20.829071593654778, -0.15971213400900874, -8.092485822876444, 20.211112433173557, 6.949398220410868, 58.108088413091195]... (total 50 values)
#
# Dataset: ./xy_data/st2_data.txt
#   roles_0: [19.18356093189963, 1.4109596774193562, 20.79142476905009, -6.810587852990023, 30.36846950643881, -1.9936858375589366, -6.599525398096256, 11.040032480092277, -2.70596009763285, 9.8817041688874]... (total 50 values)
#   roles_1: [-4.353436526999377, -13.437701272128798, 35.53632828152359, -5.252500051427655, 22.28311100237265, 10.322197273456295, 16.177180789450265, 47.57817051638952, 16.94786959459812, 40.905198117448464]... (total 50 values)
#
# Dataset: ./xy_data/stv2_data.txt
#   roles_0: [-8.591593436398162, -5.080573863122685, 31.02898666534616, 1.645597510590969, 34.776417539162196, -19.53845069165552, -3.701852074966533, 39.82387006320277, 2.597939008965926, 21.697194287787084]... (total 50 values)
#   roles_1: [9.705354565242295, 16.114656445310022, 10.730813995796549, -0.8524284732089219, 16.48008921198476, -18.400578027230782, 4.1873636021572835, 30.866209910624534, -1.8960336819129961, 8.761342871525882]... (total 50 values)
#
# Dataset: ./xy_data/m1_data.txt
#   roles_0: [-8.613901391162033, -14.976844426259309, 28.869337655948584, -1.4341673307269647, 25.15009355256785, -8.907969896224705, 17.823892020039366, 47.90924858819973, 25.631586468168514, 50.40103305792179]... (total 50 values)
#   roles_1: [-2.9999599358974334, 4.200462072649572, 33.00753268775715, -2.5641299813736245, 25.409699121557246, -15.335213333333353, -4.319218666666666, 40.981877899591936, -9.506221279510521, 18.478203501769688]... (total 50 values)
#
# Dataset: ./xy_data/friedr2_data.txt
#   roles_0: [5.058873562110402, 5.79398724375041, 23.1823373108604, 5.916503172657464, 26.80114222522741, -1.8507721098992036, -19.432965475451528, 36.79547556248563, 8.981682144589731, 102.73368019906444]... (total 50 values)
#   roles_1: [-13.322763998676177, -6.6678471187994, 14.177159557607082, -3.1681637195167407, 11.22823742052602, 14.775919986387217, 7.898757673241896, 24.578121191737623, -5.113925216696612, 23.446236886014365]... (total 50 values)
#
# Dataset: ./xy_data/t2_data.txt
#   roles_0: [-17.241138911490825, 5.7924907332067574, 36.269217770331295, -0.39158733117078576, 12.179500015308454, 12.838447070868947, 15.085371260683724, 21.17110437938513, 1.5336972849053065, 40.813712244983876]... (total 50 values)
#   roles_1: [1.5122585418348127, -5.538471437539238, 27.331300172016142, 0.9290026614422942, 36.43103685422221, -14.263001957121258, -5.086192954363496, 20.16713107598127, -5.196227617583639, 19.605453100175286]... (total 50 values)
#
# Dataset: ./xy_data/alt_data.txt
#   roles_0: [-0.2734376672017118, -2.9329614767255237, 16.695508499762077, -0.3528253466641877, 15.873693611000695, -15.653909828031717, 4.201868484362472, 16.610269279776404, -4.461594403802347, 20.98142158275317]... (total 50 values)
#   roles_1: [-2.3882986949137384, -5.826056136587115, 14.79123860870639, 7.570343720470007, 25.353443068461342, -9.192693111111122, -18.28040799999999, 32.866025762197, 1.79153567930809, 14.270523857118121]... (total 50 values)
#
# Dataset: ./xy_data/alt2_data.txt
#   roles_0: [-1.630850666666669, 2.741005333333333, 20.410419770259104, 2.7683242069147673, 15.968357505484713, 19.983149333333298, 0.10556533333333384, 28.208117925227537, 5.294109128113951, 20.19320260154379]... (total 50 values)
#   roles_1: [-15.136978666666659, -5.062490666666665, 9.573052939575556, 1.2396198517348196, 9.030945990408922, 19.27374806307542, 5.843604047033086, 37.48937269067707, 2.793605409452108, 26.59765108621525]... (total 50 values)
#
# Dataset: ./xy_data/fis1_data.txt
#   roles_0: [-12.542920622212062, 5.2392998843519285, 14.105114539599764, -1.4679080691433628, 10.553396886483148, 3.4472789538000628, -17.707250735835192, 30.024338973828982, -6.339866522690291, 19.89257123500718]... (total 50 values)
#   roles_1: [-12.135679777777762, 5.848497333333337, 19.751597288634315, -0.08746799130870139, 12.392140012274309, -1.728560769507369, -5.8247285149226995, 17.886146613897914, 0.9185380473662698, 17.29875908952902]... (total 50 values)
#
# Dataset: ./xy_data/gr1_data.txt
#   roles_0: [-8.729422819689676, 18.905958623149644, 24.56673606756958, 2.9847453638782815, 26.75152814322188, -2.3858927617521397, -5.497692307692313, 14.003180305936555, 0.2571020472686201, 27.154766864291975]... (total 50 values)
#   roles_1: [-2.022027399697534, 4.291696468285746, 24.60519016559876, 0.12892536638760232, 14.294523422514523, -13.971316639741515, -15.427215939687677, 19.426268431829854, -11.807801434967946, 39.097601979560686]... (total 50 values)
#
# Dataset: ./xy_data/m2_data.txt
#   roles_0: [9.974368585452934, -19.743620705042396, 30.078742981128652, -8.05545433486556, 43.49352616115614, -17.342647451294365, -7.02213059336358, 23.851350762767535, -2.097158648485738, 25.203908697873157]... (total 50 values)
#   roles_1: [-14.424592, 4.421616000000005, 32.59877121120211, 5.462072222291015, 13.313129773553836, 9.357808, -18.423904000000007, 35.40337300534856, 4.112386211722563, 23.54126199623863]... (total 50 values)
#
# Dataset: ./xy_data/stv1_data.txt
#   roles_0: [-6.045322797735067, -2.679094959621274, 18.710214909172418, -4.5452408962823485, 14.110711111319693, 19.320232155699358, 2.973585041352034, 26.85256242850374, -6.766012719551402, 25.491373348897458]... (total 50 values)
#   roles_1: []... (total 0 values)
#
# Dataset: ./xy_data/st1_data.txt
#   roles_0: [-1.179515783841625, 8.230967540574273, 22.19983873306913, -0.5401138269989376, 11.309037588573187, 12.099084059549739, -19.909561546840933, 20.608772122017786, -2.6317640913768923, 51.770697156763276]... (total 50 values)
#   roles_1: [-7.664196745966651, 17.318768376368887, 18.837505178245685, -3.3948998603024134, 26.23003311848137, -5.473257434116805, -1.345882713929588, 13.155822931697438, 2.653648322667068, 11.540433854767148]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX.xml
#   DFL-CLU-00000G: [15.109658341658331, -22.31648651348654, 25.20521392315285, -17.49084242038761, 46.39737271006792, -16.062329670329664, 10.34102597402598, 11.896036067208794, -0.9955031294285696, 25.529981693324686]... (total 50 values)
#   DFL-CLU-000008: [9.741061938061932, -20.628540459540464, 22.776449375270946, -6.052709983491506, 31.230492089722496, 1.4252477522477545, 5.682238761238755, 15.950543357668552, -7.9617225622127865, 19.008910885047175]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1.xml
#   DFL-CLU-00000S: [-3.396983016983015, -5.241215784215781, 17.7224097938022, 1.0205261346683323, 10.97533371448152, 12.204405594405609, 2.0700829170829183, 53.297373096419605, 7.033562897335672, 9.31293568720879]... (total 50 values)
#   DFL-CLU-00000B: [13.128967032967035, 0.3657992007992017, 35.32581922257877, -2.8102818426263743, 25.87909076930604, -13.12321078921081, -6.033871128871141, 25.834450191190133, 7.450009289191807, 11.68296947304229]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ.xml
#   DFL-CLU-00000P: [-14.92082117882117, 12.211128871128876, 34.68332637699101, 13.456260420932061, 60.68419699437566, 4.3179600399600355, -4.326643356643358, 9.362474306401598, 0.0451463272657334, 23.349645671678307]... (total 50 values)
#   DFL-CLU-00000H: [12.672292707292728, -7.261447552447547, 37.02892718123677, -4.868536029867134, 30.80908063149651, -10.13613886113885, 10.821539460539453, 37.269388119698306, -10.55637363201498, 16.55268405669131]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9.xml
#   DFL-CLU-00000I: [-16.873467532467494, 6.15152047952048, 31.69382227519481, -2.086168110415586, 26.01559915583017, -0.49209890109890037, -9.749658341658337, 47.067371261208784, 9.188113409824174, 13.495991673152844]... (total 50 values)
#   DFL-CLU-00000P: [17.583453546453526, 8.549824175824197, 22.030352162089912, -3.8124616541758245, 25.52875697305494, -17.14993306693306, -5.131404595404605, 27.999073876515475, 6.834444682107889, 13.136543869138862]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY.xml
#   DFL-CLU-00000P: [-12.586840159840142, -5.725166833166833, 39.80987591242559, -2.3111058033066874, 13.364807931138863, 2.1670359640359638, -1.0935584415584416, 10.165836552705295, 3.1333729561038948, 23.928497078831178]... (total 50 values)
#   DFL-CLU-000005: [4.642576423576418, -12.437573426573442, 13.014363662975024, -2.1569173701328688, 16.93927528742458, 3.830558441558442, 20.24359540459542, 37.30674711540261, -4.456976331831166, 15.613347541710292]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH.xml
#   DFL-CLU-00000P: [-8.757468531468541, -11.282672327672316, 36.95455977036984, 20.937296192678314, 20.408552143634584, 2.268315684315687, -0.5562187812187819, 11.702431365354872, 3.628353216134864, 15.673217420198021]... (total 50 values)
#   DFL-CLU-000011: [-6.803460539460533, -8.973420579420582, 30.040110678691303, 16.547401208112884, 117.97515319193603, 12.318417582417577, 6.795400599400594, 34.71458693945054, 5.78139402154945, 13.096504608359643]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY.xml
#   DFL-CLU-00000Q: [-7.697563436563439, 6.297339660339665, 27.06387742288844, -7.643818914431573, 38.79618859918213, -11.885715284715287, -13.106746253746252, 18.741799808522813, 7.607592901682314, 16.98889446621512]... (total 50 values)
#   DFL-CLU-00000P: [-9.953456543456555, -2.340297702297699, 14.958291568359648, 3.9960174099500496, 15.959908073284714, -0.9251448551448526, 7.442959040959031, 33.821323051996, 0.459567359060939, 20.788683317320686]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WMX_2.xml
#   DFL-CLU-00000G: [2.415677058353317, -5.855983213429262, 16.568914216336374, 1.1506295118254182, 14.148876220429097, -7.876992805755392, 19.556502797761794, 25.958327756659298, -12.416383261220135, 52.652564191703284]... (total 50 values)
#   DFL-CLU-000008: [0.6734516386890486, -6.874537170263798, 14.87664038225931, 1.8162020228009592, 12.520632568817266, 11.731229416466824, 7.439867306155074, 16.273540600925987, 3.9050255448665037, 11.944472737578263]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000001_DFL-MAT-J03WN1_2.xml
#   DFL-CLU-00000S: [8.869381294964024, 2.8858145483613096, 31.905239220097847, 1.5080486835683458, 9.137941797580176, -12.547485211830539, 3.745494804156676, 22.647536073981133, 0.9212557178769024, 40.411886696572985]... (total 50 values)
#   DFL-CLU-00000B: [-2.0481335820232704, -2.6452807531752316, 9.235940491093784, 1.122258679375062, 12.638746949543355, -3.5035452526867394, 15.274487432276391, 15.562452557636105, 2.7861004429839102, 40.61814857527071]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WQQ_2.xml
#   DFL-CLU-00000P: [3.115392486011193, 6.960784972022381, 15.483260101031496, -6.424454593937011, 16.19081489852598, -3.2065499600319773, -20.120062350119913, 41.326755802902, 4.192910257682494, 30.713852071309358]... (total 50 values)
#   DFL-CLU-00000H: [-2.863398081534772, -0.12345723421262898, 12.23882000903509, -3.2414891749621115, 31.404924844800398, 15.056442046362896, 4.597422062350126, 31.702831568069463, -1.2702462131203835, 22.43404009175163]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WR9_2.xml
#   DFL-CLU-00000I: [-5.795619504396478, 17.583470823341294, 26.271328611907272, -13.797139567289529, 50.673625804548045, 9.142773780975208, -6.207520383693042, 29.608251795984014, -12.822211738614868, 17.082513291384167]... (total 50 values)
#   DFL-CLU-00000P: [-13.233571542765784, 5.952370903277375, 25.75571306239519, 8.434903320156677, 22.487770268438357, 6.030705035971232, 2.212243005595519, 15.686029027044267, -2.524633529064749, 22.45819948301869]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WPY_2.xml
#   DFL-CLU-00000P: [-14.668539568345324, -1.4600095923261371, 29.53795220329977, 7.457336004420146, 18.422602890574584, -8.648075939248589, 7.3241390887290105, 25.044848968895288, -2.3234100038292556, 30.52211313690553]... (total 50 values)
#   DFL-CLU-000005: [13.831553956834556, -9.108721822541971, 33.92023878808634, -15.013980780621578, 22.983314367355398, 4.265734612310147, 7.639575539568349, 20.90422318871303, 8.707333731263304, 18.495610526089212]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOH_2.xml
#   DFL-CLU-00000P: [-13.623852917665863, -17.0896634692246, 31.805762480749483, 10.741227352862671, 62.66160673545641, 7.12258193445244, 6.534445243804953, 16.528698969881372, -7.930033623309988, 21.025663648799362]... (total 50 values)
#   DFL-CLU-000011: [-14.24184652278177, 2.9670199840127887, 21.54527682389257, -7.476980508669546, 17.81024800626699, 6.281534772182247, 15.410936850519564, 23.40615733485661, 6.6195256393976, 29.209251631475624]... (total 50 values)
#
# Dataset: ./data/DFL_04_03_positions_raw_observed_DFL-COM-000002_DFL-MAT-J03WOY_2.xml
#   DFL-CLU-00000Q: [-10.706360511590745, -0.5682877697841716, 28.72952827872742, 2.2555372337726616, 9.851045577922303, -1.3281270983213411, 6.932879296562755, 12.362488936633094, 5.879894049446522, 22.042820871019032]... (total 50 values)
#   DFL-CLU-00000P: [-14.693524380495623, 3.3580935251798687, 35.613513824690834, -6.210444954917987, 41.518086904731774, 15.640696243005598, -10.671746602717828, 36.170729434743585, -7.646254965367224, 34.45728584122416]... (total 50 values)

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load JSON data
with open("merged.json", "r") as file:  # Update with actual filename
    data = json.load(file)

# Assume `ground_truth` is a dictionary mapping (dataset, team_key) to labels
ground_truth = {  # Example labels (replace with actual labels)
    ("./xy_data/alt2_data.txt", "roles_0"): 4231,
    ("./xy_data/alt2_data.txt", "roles_1"): 442,

    ("./xy_data/alt_data.txt", "roles_0"): 4231,
    ("./xy_data/alt_data.txt", "roles_1"): 442,

    ("./xy_data/fis1_data.txt", "roles_0"): 442,
    ("./xy_data/fis1_data.txt", "roles_1"): 4231,

    ("./xy_data/fis2_data.txt", "roles_0"): 442,
    ("./xy_data/fis2_data.txt", "roles_1"): 4231,

    ("./xy_data/fried1_data.txt", "roles_1"): 442,

    ("./xy_data/friedr2_data.txt", "roles_0"): 442,
    ("./xy_data/friedr2_data.txt", "roles_1"): 442,

    ("./xy_data/gr1_data.txt.txt", "roles_0"): 4231,
    ("./xy_data/gr1_data.txt.txt", "roles_1"): 352,

    ("./xy_data/gr2_data.txt", "roles_0"): 4231,
    ("./xy_data/gr2_data.txt", "roles_1"): 352,

    ("./xy_data/m1_data.txt", "roles_0"): 442,
    ("./xy_data/m1_data.txt", "roles_1"): 442,

    ("./xy_data/m2_data.txt", "roles_0"): 442,
    ("./xy_data/m2_data.txt", "roles_1"): 442,

    ("./xy_data/st1_data.txt", "roles_0"): 4231,
    ("./xy_data/st1_data.txt", "roles_1"): 4231,

    ("./xy_data/st2_data.txt", "roles_0"): 4231,
    ("./xy_data/st2_data.txt", "roles_1"): 4231,

    ("./xy_data/stv1_data.txt", "roles_0"): 4231,

    ("./xy_data/stv2_data.txt", "roles_0"): 352,
    ("./xy_data/stv2_data.txt", "roles_1"): 442,

    # ("./xy_data/t1_data.txt", "roles_0"): 4141,
    ("./xy_data/t1_data.txt.txt", "roles_1"): 442,

    # ("./xy_data/t2_data.txt", "roles_0"): 4141,
    ("./xy_data/t2_data.txt", "roles_0"): 442,

    #
    ("df_A_clip1", "roles_0"): 352,
    ("df_A_clip2", "roles_0"): 352,
    ("df_B_clip1", "roles_0"): 352,
    ("df_C_clip1", "roles_0"): 352,
    ("df_C_clip2", "roles_0"): 352



}
X, y = [], []

# Extract feature vectors and labels
for dataset_key, teams in data.items():
    for team_key, players in teams.items():
        if (dataset_key, team_key) in ground_truth:
            feature_vector = []
            x_coords, y_coords = [], []
            for player_id, stats in players.items():
                mean = stats["mean"]
                x_coords.append(mean[0])
                y_coords.append(mean[1])
            
            # Calculate overall mean for x and y
            overall_mean_x = np.mean(x_coords)
            overall_mean_y = np.mean(y_coords)
            
            feature_vector.extend([overall_mean_x, overall_mean_y])
            X.append(feature_vector)
            y.append(ground_truth[(dataset_key, team_key)])

# Convert to NumPy arrays
X = np.array(X)
y = np.array(y)

# %%
# Split data into Training (80%) and Testing (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42, shuffle=True)

# Normalize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5,metric="euclidean")  # You can tweak 'n_neighbors'
knn.fit(X_train, y_train)

# Predictions
y_pred = knn.predict(X_test)

# Evaluate Model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 44.44%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          352       0.00      0.00      0.00         0
#          442       0.50      0.40      0.44         5
#         4231       0.50      0.50      0.50         4
#
#     accuracy                           0.44         9
#    macro avg       0.33      0.30      0.31         9
# weighted avg       0.50      0.44      0.47         9
# /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/stefanbartl/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
